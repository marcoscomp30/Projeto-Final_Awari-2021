# %% [markdown]
# ## Projeção

# %%
import pandas as pd
import numpy as np
pd.set_option('display.float_format', '{:.2f}'.format) 
#Comando para evitar notações cientificas, nº grandes

# %%
# Importando CSV
table = pd.read_csv('Empresas_Projeto_Awari_ML.csv',error_bad_lines=False, delimiter= ';',
                    encoding='ISO-8859-1',thousands=",", decimal=".")

# %%
table
# Out:
#     Empresa          Descriçao    2011    2012    2013    2014    2015  \
# 0      MGLU    Receita_liquida   6,419   7,665   8,109   9,779   8,978
# 1      MGLU             Custos  -4,275  -5,146  -5,825  -7,086  -6,399
# 2      MGLU    Resultado_bruto   2,144   2,519   2,284   2,693   2,579
# 3      MGLU     Despesas_oper.  -1,930  -2,370  -1,908  -2,201  -2,239
# 4      MGLU   Res._operacional     214     149     376     492     340
# ..      ...                ...     ...     ...     ...     ...     ...
# 137    GUAR          Outros_PC     462     618     825   1,174   1,376
# 138    GUAR  Passivo_Nao_Circ.     650     718     688   1,122     927
# 139    GUAR        Emprest._LP     426     476     406     790     581
# 140    GUAR         Outros_PNC     224     242     281     331     345
# 141    GUAR    Patrimonio_Liq.   2,238   2,526   2,829   3,175   3,390
#
#        2016    2017     2018     2019     2020
# 0     9,508  11,984   15,590   19,886   29,177
# ...

# %%
table.index
# Out:
# RangeIndex(start=0, stop=142, step=1)

# %%
table2 = table.T
table2
# Out:
#                        0        1                2               3    \
# Empresa               MGLU     MGLU             MGLU            MGLU
# Descriçao  Receita_liquida   Custos  Resultado_bruto  Despesas_oper.
# 2011                 6,419   -4,275            2,144          -1,930
# 2012                 7,665   -5,146            2,519          -2,370
# 2013                 8,109   -5,825            2,284          -1,908
# 2014                 9,779   -7,086            2,693          -2,201
# 2015                 8,978   -6,399            2,579          -2,239
# 2016                 9,508   -6,586            2,922          -2,341
# 2017                11,984   -8,378            3,606          -2,718
# 2018                15,590  -11,053            4,537          -3,455
# 2019                19,886  -14,332            5,554          -4,265
# 2020                29,177  -21,657            7,520          -6,695
#
# ...

# %%
table2
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-10-fd5f4ef78c21> in <module>
# ----> 1 table.groupby(['Empresa','Descriçao']).mean()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, numeric_only)
#    1391         Name: B, dtype: float64
#    1392         """
# -> 1393         return self._cython_agg_general(
#    1394             "mean",
#    1395             alt=lambda x, axis: Series(x).mean(numeric_only=numeric_only),
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1019         self, how: str, alt=None, numeric_only: bool = True, min_count: int = -1
#    1020     ) -> DataFrame:
# -> 1021         agg_blocks, agg_items = self._cython_agg_blocks(
#    1022             how, alt=alt, numeric_only=numeric_only, min_count=min_count
# ...

# %%
#table2.to_csv('Projecao_T.csv', sep = ';', index = True)
